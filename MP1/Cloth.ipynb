# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv(r'C:\Users\Tobi\Desktop\BI\sales.csv')

# %%
list(df)
# Out:
# ['Store id',
#  'Tshirt',
#  'Tank top',
#  'Halter top',
#  'Turtleneck',
#  'Tube top',
#  'Sweater']

# %%
df.describe().round(2)
# Out:
#        Store id     Tshirt  Tank top  Halter top  Turtleneck  Tube top  \
# count    440.00     440.00    440.00      440.00      440.00    440.00
# mean     220.50   11959.89   5807.52     8003.34     3067.52   2881.40
# std      127.16   12471.50   7386.34     9603.46     5007.04   4739.06
# min        1.00       2.00     55.00        3.00       25.00      2.00
# 25%      110.75    3139.00   1552.25     2102.00      726.75    254.50
# 50%      220.50    8179.00   3666.50     4791.50     1562.50    792.50
# 75%      330.25   16853.75   7212.00    10385.25     3551.50   3873.00
# max      440.00  104972.00  77873.00    97393.00    66900.00  40066.00
#
#         Sweater
# count    440.00
# mean    1529.94
# std     2951.81
# min        2.00
# 25%      398.00
# 50%      952.50
# 75%     1802.00
# max    50710.00

# %%
df.isnull().sum()
# Out:
# Store id      0
# Tshirt        0
# Tank top      0
# Halter top    0
# Turtleneck    0
# Tube top      0
# Sweater       0
# dtype: int64

# %%
df.drop("Store id", axis=1).sum().plot(kind="bar")

plt.title("Total Sales per Clothing Item")
plt.ylabel("Units Sold")
plt.show()

# %% [markdown]
# I couldn't think of many fun graphs so I made a pie chart of the sales from the first store in the data set

# %%
store1.plot(
    kind="pie",
    autopct='%1.1f%%',
    legend=False,
    figsize=(6,6)
)

plt.title("Store 1 Sales Distribution by Item")
plt.ylabel("")
plt.show()
